# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
#code here
plt.figure(figsize=(10,6.5))
plt.plot(x, cos, color='r', label='Cosx')
plt.plot(x, cos3, color='g', label='3 Cosx', linestyle='dashed')
plt.plot(x, sin, color='b', label='Sin(x-90)', linestyle='dashdot')
plt.plot(x, sin2, color='#d0d045ff', label='2 Sinx', marker='x', ms=5, ls='')
plt.legend(loc='center', prop={'size': 8})
plt.xlabel('X-Axis Label')
plt.ylabel('Y-Axis Label')
plt.title('Grafik Cos Sin', fontsize=11)
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
